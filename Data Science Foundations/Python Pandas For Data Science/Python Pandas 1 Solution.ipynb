# %% [markdown]
# # What can we do with Pandas?
#
# In this example, we'll be working w/ data from the 2023-24 Boston Celtics

# %%
# Before we analyze anything, we need to import pandas
import pandas as pd

# %% [markdown]
# ### Loading data from a csv file
#
# We can load data into Pandas from a csv (comma-separated variable) file. This data represents the Celtics roster.

# %%
celtics = pd.read_csv('boston_celtics_2023_2024.csv')

# %% [markdown]
# ### Selecting Data (Previewing)
#
# Let's examine the first 10 rows of our data.

# %%
celtics.head(10)
# Out:
#    number              player position height  weight       birth_date  \
# 0      11    Payton Pritchard       PG    6-1     195  January 28 1998
# 1      30          Sam Hauser       SF    6-8     215  December 8 1997
# 2       0        Jayson Tatum       PF    6-8     210     March 3 1998
# 3       9       Derrick White       SG    6-4     190      July 2 1994
# 4       7        Jaylen Brown       SF    6-6     223  October 24 1996
# 5       4        Jrue Holiday       PG    6-4     205     June 12 1990
# 6      42          Al Horford        C    6-9     240      June 3 1986
# 7      40         Luke Kornet        C    7-2     250     July 15 1995
# 8       8  Kristaps Porziņģis        C    7-2     240    August 2 1995
# 9      12      Oshae Brissett       SF    6-7     210     June 20 1998
#
#   country_code experience                             college
# 0           us          3                              Oregon
# 1           us          2                  Marquette Virginia
# 2           us          6                                Duke
# 3           us          6  Colorado-Colorado Springs Colorado
# 4           us          7                          California
# 5           us         14                                UCLA
# 6           do         16                             Florida
# 7           us          6                          Vanderbilt
# 8           lv          7                                 NaN
# 9           ca          4                            Syracuse

# %% [markdown]
# ### Inspecting the structure of the data frame.
#
# Let's see what the data looks like.

# %%
celtics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   number        17 non-null     int64
#  1   player        17 non-null     object
#  2   position      17 non-null     object
#  3   height        17 non-null     object
#  4   weight        17 non-null     int64
#  5   birth_date    17 non-null     object
#  6   country_code  17 non-null     object
#  7   experience    17 non-null     object
#  8   college       16 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 1.3+ KB

# %% [markdown]
# ### Selecting Data by column
#
# What colleges did the team go to?

# %%
celtics.college
# Out:
# 0                                 Oregon
# 1                     Marquette Virginia
# 2                                   Duke
# 3     Colorado-Colorado Springs Colorado
# 4                             California
# 5                                   UCLA
# 6                                Florida
# 7                             Vanderbilt
# 8                                    NaN
# 9                               Syracuse
# 10                                Kansas
# 11                 Utah State University
# 12                        Michigan State
# 13                             Tennessee
# 14                              Arkansas
# 15                               Alabama
# 16                   Rice University USC
# Name: college, dtype: object

# %% [markdown]
# Let's inspect the data types

# %%
print(type(celtics))
print(type(celtics.college))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### Selecting Multiple Columns
#
# Well, that isn't useful. Let's add the player names too.

# %%
celtics[['player','college']]
# Out:
#                  player                             college
# 0      Payton Pritchard                              Oregon
# 1            Sam Hauser                  Marquette Virginia
# 2          Jayson Tatum                                Duke
# 3         Derrick White  Colorado-Colorado Springs Colorado
# 4          Jaylen Brown                          California
# 5          Jrue Holiday                                UCLA
# 6            Al Horford                             Florida
# 7           Luke Kornet                          Vanderbilt
# 8    Kristaps Porziņģis                                 NaN
# 9        Oshae Brissett                            Syracuse
# 10       Svi Mykhailiuk                              Kansas
# 11        Neemias Queta               Utah State University
# 12   Xavier Tillman Sr.                      Michigan State
# 13       Jaden Springer                           Tennessee
# 14         Jordan Walsh                            Arkansas
# 15     JD Davison  (TW)                             Alabama
# 16  Drew Peterson  (TW)                 Rice University USC

# %% [markdown]
# Let's check the data type again. (HINT: It's different when selecting multiple columns!)

# %%
type(celtics[['player','college']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Selecting Rows
#
# iloc is a way to select rows based on integer location. Let's select Jaylen Brown.

# %%
celtics.iloc[4]
# Out:
# number                        7
# player             Jaylen Brown
# position                     SF
# height                      6-6
# weight                      223
# birth_date      October 24 1996
# country_code                 us
# experience                    7
# college              California
# Name: 4, dtype: object

# %% [markdown]
# We can also select them using python's **slice** notation. The second number is *non-inclusive*

# %%
celtics.iloc[2:7]
# Out:
#    number         player position height  weight       birth_date  \
# 2       0   Jayson Tatum       PF    6-8     210     March 3 1998
# 3       9  Derrick White       SG    6-4     190      July 2 1994
# 4       7   Jaylen Brown       SF    6-6     223  October 24 1996
# 5       4   Jrue Holiday       PG    6-4     205     June 12 1990
# 6      42     Al Horford        C    6-9     240      June 3 1986
#
#   country_code experience                             college
# 2           us          6                                Duke
# 3           us          6  Colorado-Colorado Springs Colorado
# 4           us          7                          California
# 5           us         14                                UCLA
# 6           do         16                             Florida

# %% [markdown]
# ### Selecting Rows by Logic
#
# Who's our fives? (Centers)

# %%
celtics[celtics.position == 'C']
# Out:
#     number              player position height  weight     birth_date  \
# 6       42          Al Horford        C    6-9     240    June 3 1986
# 7       40         Luke Kornet        C    7-2     250   July 15 1995
# 8        8  Kristaps Porziņģis        C    7-2     240  August 2 1995
# 11      88       Neemias Queta        C    7-0     245   July 13 1999
#
#    country_code experience                college
# 6            do         16                Florida
# 7            us          6             Vanderbilt
# 8            lv          7                    NaN
# 11           pt          2  Utah State University

# %% [markdown]
# Who has a birthday coming up?

# %%
celtics[celtics.birth_date.str.contains('June')]
# Out:
#     number          player position height  weight    birth_date country_code  \
# 5        4    Jrue Holiday       PG    6-4     205  June 12 1990           us
# 6       42      Al Horford        C    6-9     240   June 3 1986           do
# 9       12  Oshae Brissett       SF    6-7     210  June 20 1998           ca
# 10      50  Svi Mykhailiuk       SF    6-7     205  June 10 1997           ua
#
#    experience   college
# 5          14      UCLA
# 6          16   Florida
# 9           4  Syracuse
# 10          5    Kansas

# %% [markdown]
# Who plays guard?

# %%
celtics[(celtics.position == 'PG') | (celtics.position =='SG')]
# Out:
#     number            player position height  weight         birth_date  \
# 0       11  Payton Pritchard       PG    6-1     195    January 28 1998
# 3        9     Derrick White       SG    6-4     190        July 2 1994
# 5        4      Jrue Holiday       PG    6-4     205       June 12 1990
# 13      44    Jaden Springer       PG    6-4     204  September 25 2002
# 15      20  JD Davison  (TW)       SG    6-1     195     October 3 2002
#
#    country_code experience                             college
# 0            us          3                              Oregon
# 3            us          6  Colorado-Colorado Springs Colorado
# 5            us         14                                UCLA
# 13           us          2                           Tennessee
# 15           us          1                             Alabama

# %% [markdown]
# Which players weren't born in the US, but attended college?

# %%
celtics[(celtics.country_code != 'us') & (celtics.college)]
# Out:
#     number          player position height  weight    birth_date country_code  \
# 6       42      Al Horford        C    6-9     240   June 3 1986           do
# 9       12  Oshae Brissett       SF    6-7     210  June 20 1998           ca
# 10      50  Svi Mykhailiuk       SF    6-7     205  June 10 1997           ua
# 11      88   Neemias Queta        C    7-0     245  July 13 1999           pt
#
#    experience                college
# 6          16                Florida
# 9           4               Syracuse
# 10          5                 Kansas
# 11          2  Utah State University

# %% [markdown]
# [HINT: The query above is looking for a defined cell, let's see what happens we find an undefined cell)

# %%
# This is a crappy way to hunt down NaNs. 
celtics[celtics.isnull().any(axis=1)]
# Out:
#    number              player position height  weight     birth_date  \
# 8       8  Kristaps Porziņģis        C    7-2     240  August 2 1995
#
#   country_code experience college
# 8           lv          7     NaN

# %% [markdown]
# Who went to college in California?

# %%
celtics[celtics.college.isin(['California','UCLA','USC'])]
# Out:
#    number        player position height  weight       birth_date country_code  \
# 4       7  Jaylen Brown       SF    6-6     223  October 24 1996           us
# 5       4  Jrue Holiday       PG    6-4     205     June 12 1990           us
#
#   experience     college
# 4          7  California
# 5         14        UCLA

# %% [markdown]
# ### Setting Indices
#
# (This is using pandas' loc, not iloc)
#
# Let's set the starting lineup!

# %%
starting_lineup = celtics.loc[[2,3,4,5,8]]
starting_lineup
# Out:
#    number              player position height  weight       birth_date  \
# 2       0        Jayson Tatum       PF    6-8     210     March 3 1998
# 3       9       Derrick White       SG    6-4     190      July 2 1994
# 4       7        Jaylen Brown       SF    6-6     223  October 24 1996
# 5       4        Jrue Holiday       PG    6-4     205     June 12 1990
# 8       8  Kristaps Porziņģis        C    7-2     240    August 2 1995
#
#   country_code experience                             college
# 2           us          6                                Duke
# 3           us          6  Colorado-Colorado Springs Colorado
# 4           us          7                          California
# 5           us         14                                UCLA
# 8           lv          7                                 NaN

# %% [markdown]
# We're going to use this starting a lineup a lot. Wouldn't it be nice if we could update the indexes?

# %%
new_starting_lineup = starting_lineup.reset_index()
new_starting_lineup
# Out:
#    index  number              player position height  weight       birth_date  \
# 0      2       0        Jayson Tatum       PF    6-8     210     March 3 1998
# 1      3       9       Derrick White       SG    6-4     190      July 2 1994
# 2      4       7        Jaylen Brown       SF    6-6     223  October 24 1996
# 3      5       4        Jrue Holiday       PG    6-4     205     June 12 1990
# 4      8       8  Kristaps Porziņģis        C    7-2     240    August 2 1995
#
#   country_code experience                             college
# 0           us          6                                Duke
# 1           us          6  Colorado-Colorado Springs Colorado
# 2           us          7                          California
# 3           us         14                                UCLA
# 4           lv          7                                 NaN

# %% [markdown]
# Hmm. So that's cool, but now I have a wasted data frame. 'starting_lineup' didn't update...

# %%
starting_lineup
# Out:
#    number              player position height  weight       birth_date  \
# 2       0        Jayson Tatum       PF    6-8     210     March 3 1998
# 3       9       Derrick White       SG    6-4     190      July 2 1994
# 4       7        Jaylen Brown       SF    6-6     223  October 24 1996
# 5       4        Jrue Holiday       PG    6-4     205     June 12 1990
# 8       8  Kristaps Porziņģis        C    7-2     240    August 2 1995
#
#   country_code experience                             college
# 2           us          6                                Duke
# 3           us          6  Colorado-Colorado Springs Colorado
# 4           us          7                          California
# 5           us         14                                UCLA
# 8           lv          7                                 NaN

# %% [markdown]
# Let's fix that.

# %%
starting_lineup.reset_index(inplace=True)
starting_lineup
# Out:
#    index  number              player position height  weight       birth_date  \
# 0      2       0        Jayson Tatum       PF    6-8     210     March 3 1998
# 1      3       9       Derrick White       SG    6-4     190      July 2 1994
# 2      4       7        Jaylen Brown       SF    6-6     223  October 24 1996
# 3      5       4        Jrue Holiday       PG    6-4     205     June 12 1990
# 4      8       8  Kristaps Porziņģis        C    7-2     240    August 2 1995
#
#   country_code experience                             college
# 0           us          6                                Duke
# 1           us          6  Colorado-Colorado Springs Colorado
# 2           us          7                          California
# 3           us         14                                UCLA
# 4           lv          7                                 NaN

# %% [markdown]
# That's much better. I don't really need that second index column. Get outta here.

# %%
starting_lineup.reset_index(drop=True, inplace=True)
starting_lineup
# Out:
#    index  number              player position height  weight       birth_date  \
# 0      2       0        Jayson Tatum       PF    6-8     210     March 3 1998
# 1      3       9       Derrick White       SG    6-4     190      July 2 1994
# 2      4       7        Jaylen Brown       SF    6-6     223  October 24 1996
# 3      5       4        Jrue Holiday       PG    6-4     205     June 12 1990
# 4      8       8  Kristaps Porziņģis        C    7-2     240    August 2 1995
#
#   country_code experience                             college
# 0           us          6                                Duke
# 1           us          6  Colorado-Colorado Springs Colorado
# 2           us          7                          California
# 3           us         14                                UCLA
# 4           lv          7                                 NaN

# %% [markdown]
# HA! Tricked you. That doesn't work. Those columns are still there. It's a bit of an either or.
#
# This makes **inplace=True** obsolete when you don't need the index column, because the solution is to reassign to the same variable...
#
# ```NOTE: It isn't unusual for this to have unexpected behavior. If you plan to do something like this, I recommend doing it right away.```

# %%
starting_lineup = celtics.loc[[2,3,4,5,8]]
starting_lineup = starting_lineup.reset_index(drop=True)
starting_lineup
# Out:
#    number              player position height  weight       birth_date  \
# 0       0        Jayson Tatum       PF    6-8     210     March 3 1998
# 1       9       Derrick White       SG    6-4     190      July 2 1994
# 2       7        Jaylen Brown       SF    6-6     223  October 24 1996
# 3       4        Jrue Holiday       PG    6-4     205     June 12 1990
# 4       8  Kristaps Porziņģis        C    7-2     240    August 2 1995
#
#   country_code experience                             college
# 0           us          6                                Duke
# 1           us          6  Colorado-Colorado Springs Colorado
# 2           us          7                          California
# 3           us         14                                UCLA
# 4           lv          7                                 NaN
